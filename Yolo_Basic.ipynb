# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/pushpavanthar/EIP2/blob/master/Yolo_Basic.ipynb)

# %%
# https://keras.io/
# !pip install -q keras
import keras

import keras
from keras.datasets import cifar10
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Input, AveragePooling2D, merge, Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Concatenate
from keras.optimizers import Adam
from keras.layers.advanced_activations import LeakyReLU
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda
from keras.layers.merge import concatenate

# this part will prevent tensorflow to allocate all the avaliable GPU Memory
# backend
import tensorflow as tf
from keras import backend as k

# Don't pre-allocate memory; allocate as-needed
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))

# Hyperparameters
batch_size = 128
num_classes = 10
epochs = 30
l = 10
num_filter = 20

# %%
# Load CIFAR10 Data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
img_height, img_width, channel = x_train.shape[1],x_train.shape[2],x_train.shape[3]

# convert to one hot encoing 
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)

# %%
import numpy as np
input = Input(shape=(img_height, img_width, channel,))

# Layer 1
layer1_x = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_1', use_bias=False)(input)
layer1_x = BatchNormalization(name='norm_1')(layer1_x)
layer1_x = LeakyReLU(alpha=0.1)(layer1_x)
layer1_x = MaxPooling2D(pool_size=(2, 2))(layer1_x)

# Layer 2
layer2_x = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_2', use_bias=False)(layer1_x)
layer2_x = BatchNormalization(name='norm_2')(layer2_x)
layer2_x = LeakyReLU(alpha=0.1)(layer2_x)
layer2_x = MaxPooling2D(pool_size=(2, 2))(layer2_x)

# Layer 3
layer3_x = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_3', use_bias=False)(layer2_x)
layer3_x = BatchNormalization(name='norm_3')(layer3_x)
layer3_x = LeakyReLU(alpha=0.1)(layer3_x)

# Layer 4
layer4_x = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_4', use_bias=False)(layer3_x)
layer4_x = BatchNormalization(name='norm_4')(layer4_x)
layer4_x = LeakyReLU(alpha=0.1)(layer4_x)

# Layer 5
layer5_x = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_5', use_bias=False)(layer4_x)
layer5_x = BatchNormalization(name='norm_5')(layer5_x)
layer5_x = LeakyReLU(alpha=0.1)(layer5_x)
layer5_x = MaxPooling2D(pool_size=(2, 2))(layer5_x)

# Layer 6
layer6_x = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_6', use_bias=False)(layer5_x)
layer6_x = BatchNormalization(name='norm_6')(layer6_x)
layer6_x = LeakyReLU(alpha=0.1)(layer6_x)

# Layer 7
layer7_x = Conv2D(128, (1,1), strides=(1,1), padding='same', name='conv_7', use_bias=False)(layer6_x)
layer7_x = BatchNormalization(name='norm_7')(layer7_x)
layer7_x = LeakyReLU(alpha=0.1)(layer7_x)

# Layer 8
layer8_x = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_8', use_bias=False)(layer7_x)
layer8_x = BatchNormalization(name='norm_8')(layer8_x)
layer8_x = LeakyReLU(alpha=0.1)(layer8_x)
layer8_x = MaxPooling2D(pool_size=(2, 2))(layer8_x)

# Layer 9
layer9_x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_9', use_bias=False)(layer8_x)
layer9_x = BatchNormalization(name='norm_9')(layer9_x)
layer9_x = LeakyReLU(alpha=0.1)(layer9_x)

# Layer 10
layer10_x = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_10', use_bias=False)(layer9_x)
layer10_x = BatchNormalization(name='norm_10')(layer10_x)
layer10_x = LeakyReLU(alpha=0.1)(layer10_x)

# Layer 11
layer11_x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_11', use_bias=False)(layer10_x)
layer11_x = BatchNormalization(name='norm_11')(layer11_x)
layer11_x = LeakyReLU(alpha=0.1)(layer11_x)

# Layer 12
layer12_x = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_12', use_bias=False)(layer11_x)
layer12_x = BatchNormalization(name='norm_12')(layer12_x)
layer12_x = LeakyReLU(alpha=0.1)(layer12_x)

skip_connection = layer12_x

# Layer 13
layer13_x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_13', use_bias=False)(layer12_x)
layer13_x = BatchNormalization(name='norm_13')(layer13_x)
layer13_x = LeakyReLU(alpha=0.1)(layer13_x)




layer13_x = MaxPooling2D(pool_size=(2, 2))(layer13_x)

# Layer 14
layer14_x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_14', use_bias=False)(layer13_x)
layer14_x = BatchNormalization(name='norm_14')(layer14_x)
layer14_x = LeakyReLU(alpha=0.1)(layer14_x)

# Layer 15
layer15_x = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_15', use_bias=False)(layer14_x)
layer15_x = BatchNormalization(name='norm_15')(layer15_x)
layer15_x = LeakyReLU(alpha=0.1)(layer15_x)

# Layer 16
layer16_x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_16', use_bias=False)(layer15_x)
layer16_x = BatchNormalization(name='norm_16')(layer16_x)
layer16_x = LeakyReLU(alpha=0.1)(layer16_x)

# Layer 17
layer17_x = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_17', use_bias=False)(layer16_x)
layer17_x = BatchNormalization(name='norm_17')(layer17_x)
layer17_x = LeakyReLU(alpha=0.1)(layer17_x)

# Layer 18
layer18_x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_18', use_bias=False)(layer17_x)
layer18_x = BatchNormalization(name='norm_18')(layer18_x)
layer18_x = LeakyReLU(alpha=0.1)(layer18_x)

# Layer 19
layer19_x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_19', use_bias=False)(layer18_x)
layer19_x = BatchNormalization(name='norm_19')(layer19_x)
layer19_x = LeakyReLU(alpha=0.1)(layer19_x)

# Layer 20
layer20_x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_20', use_bias=False)(layer19_x)
layer20_x = BatchNormalization(name='norm_20')(layer20_x)
layer20_x = LeakyReLU(alpha=0.1)(layer20_x)

# Layer 21
skip_connection = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_21', use_bias=False)(skip_connection)
skip_connection = BatchNormalization(name='norm_21')(skip_connection)
skip_connection = LeakyReLU(alpha=0.1)(skip_connection)
skip_connection = Lambda(space_to_depth_x2)(skip_connection)

layer20_x = concatenate([skip_connection, layer20_x])

# Layer 22
layer22_x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_22', use_bias=False)(layer20_x)
layer22_x = BatchNormalization(name='norm_22')(layer22_x)
layer22_x = LeakyReLU(alpha=0.1)(layer22_x)

# Layer 23
layer23_x = Flatten()(layer22_x)

output = Dense(num_classes, activation='softmax')(layer23_x)

# %%
model = Model(inputs=[input], outputs=[output])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 32, 32, 32)   864         input_4[0][0]
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 32, 32, 32)   128         conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)      (None, 32, 32, 32)   0           norm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 16, 16, 32)   0           leaky_re_lu_67[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 16, 16, 64)   18432       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# norm_2 (BatchNormalization)     (None, 16, 16, 64)   256         conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)      (None, 16, 16, 64)   0           norm_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 8, 8, 64)     0           leaky_re_lu_68[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 8, 8, 128)    73728       max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# norm_3 (BatchNormalization)     (None, 8, 8, 128)    512         conv_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)      (None, 8, 8, 128)    0           norm_3[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 8, 8, 64)     8192        leaky_re_lu_69[0][0]
# __________________________________________________________________________________________________
# norm_4 (BatchNormalization)     (None, 8, 8, 64)     256         conv_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)      (None, 8, 8, 64)     0           norm_4[0][0]
# __________________________________________________________________________________________________
# conv_5 (Conv2D)                 (None, 8, 8, 128)    73728       leaky_re_lu_70[0][0]
# __________________________________________________________________________________________________
# norm_5 (BatchNormalization)     (None, 8, 8, 128)    512         conv_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)      (None, 8, 8, 128)    0           norm_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 4, 4, 128)    0           leaky_re_lu_71[0][0]
# __________________________________________________________________________________________________
# conv_6 (Conv2D)                 (None, 4, 4, 256)    294912      max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# norm_6 (BatchNormalization)     (None, 4, 4, 256)    1024        conv_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)      (None, 4, 4, 256)    0           norm_6[0][0]
# __________________________________________________________________________________________________
# conv_7 (Conv2D)                 (None, 4, 4, 128)    32768       leaky_re_lu_72[0][0]
# __________________________________________________________________________________________________
# norm_7 (BatchNormalization)     (None, 4, 4, 128)    512         conv_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)      (None, 4, 4, 128)    0           norm_7[0][0]
# __________________________________________________________________________________________________
# conv_8 (Conv2D)                 (None, 4, 4, 256)    294912      leaky_re_lu_73[0][0]
# __________________________________________________________________________________________________
# norm_8 (BatchNormalization)     (None, 4, 4, 256)    1024        conv_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)      (None, 4, 4, 256)    0           norm_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 2, 2, 256)    0           leaky_re_lu_74[0][0]
# __________________________________________________________________________________________________
# conv_9 (Conv2D)                 (None, 2, 2, 512)    1179648     max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# norm_9 (BatchNormalization)     (None, 2, 2, 512)    2048        conv_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_75 (LeakyReLU)      (None, 2, 2, 512)    0           norm_9[0][0]
# __________________________________________________________________________________________________
# conv_10 (Conv2D)                (None, 2, 2, 256)    131072      leaky_re_lu_75[0][0]
# __________________________________________________________________________________________________
# norm_10 (BatchNormalization)    (None, 2, 2, 256)    1024        conv_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_76 (LeakyReLU)      (None, 2, 2, 256)    0           norm_10[0][0]
# __________________________________________________________________________________________________
# conv_11 (Conv2D)                (None, 2, 2, 512)    1179648     leaky_re_lu_76[0][0]
# __________________________________________________________________________________________________
# norm_11 (BatchNormalization)    (None, 2, 2, 512)    2048        conv_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_77 (LeakyReLU)      (None, 2, 2, 512)    0           norm_11[0][0]
# __________________________________________________________________________________________________
# conv_12 (Conv2D)                (None, 2, 2, 256)    131072      leaky_re_lu_77[0][0]
# __________________________________________________________________________________________________
# norm_12 (BatchNormalization)    (None, 2, 2, 256)    1024        conv_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_78 (LeakyReLU)      (None, 2, 2, 256)    0           norm_12[0][0]
# __________________________________________________________________________________________________
# conv_13 (Conv2D)                (None, 2, 2, 512)    1179648     leaky_re_lu_78[0][0]
# __________________________________________________________________________________________________
# norm_13 (BatchNormalization)    (None, 2, 2, 512)    2048        conv_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_79 (LeakyReLU)      (None, 2, 2, 512)    0           norm_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 1, 1, 512)    0           leaky_re_lu_79[0][0]
# __________________________________________________________________________________________________
# conv_14 (Conv2D)                (None, 1, 1, 1024)   4718592     max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# norm_14 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_80 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_14[0][0]
# __________________________________________________________________________________________________
# conv_15 (Conv2D)                (None, 1, 1, 512)    524288      leaky_re_lu_80[0][0]
# __________________________________________________________________________________________________
# norm_15 (BatchNormalization)    (None, 1, 1, 512)    2048        conv_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_81 (LeakyReLU)      (None, 1, 1, 512)    0           norm_15[0][0]
# __________________________________________________________________________________________________
# conv_16 (Conv2D)                (None, 1, 1, 1024)   4718592     leaky_re_lu_81[0][0]
# __________________________________________________________________________________________________
# norm_16 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_82 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_16[0][0]
# __________________________________________________________________________________________________
# conv_17 (Conv2D)                (None, 1, 1, 512)    524288      leaky_re_lu_82[0][0]
# __________________________________________________________________________________________________
# norm_17 (BatchNormalization)    (None, 1, 1, 512)    2048        conv_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_83 (LeakyReLU)      (None, 1, 1, 512)    0           norm_17[0][0]
# __________________________________________________________________________________________________
# conv_18 (Conv2D)                (None, 1, 1, 1024)   4718592     leaky_re_lu_83[0][0]
# __________________________________________________________________________________________________
# norm_18 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_84 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_18[0][0]
# __________________________________________________________________________________________________
# conv_19 (Conv2D)                (None, 1, 1, 1024)   9437184     leaky_re_lu_84[0][0]
# __________________________________________________________________________________________________
# norm_19 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_19[0][0]
# __________________________________________________________________________________________________
# conv_21 (Conv2D)                (None, 2, 2, 64)     16384       leaky_re_lu_78[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_85 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_19[0][0]
# __________________________________________________________________________________________________
# norm_21 (BatchNormalization)    (None, 2, 2, 64)     256         conv_21[0][0]
# __________________________________________________________________________________________________
# conv_20 (Conv2D)                (None, 1, 1, 1024)   9437184     leaky_re_lu_85[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_87 (LeakyReLU)      (None, 2, 2, 64)     0           norm_21[0][0]
# __________________________________________________________________________________________________
# norm_20 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_20[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1, 1, 256)    0           leaky_re_lu_87[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_86 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_20[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 1, 1, 1280)   0           lambda_4[0][0]
#                                                                  leaky_re_lu_86[0][0]
# __________________________________________________________________________________________________
# conv_22 (Conv2D)                (None, 1, 1, 1024)   11796480    concatenate_4[0][0]
# __________________________________________________________________________________________________
# norm_22 (BatchNormalization)    (None, 1, 1, 1024)   4096        conv_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_88 (LeakyReLU)      (None, 1, 1, 1024)   0           norm_22[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 1024)         0           leaky_re_lu_88[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           10250       flatten_4[0][0]
# ==================================================================================================
# Total params: 50,541,802
# Trainable params: 50,521,130
# Non-trainable params: 20,672
# __________________________________________________________________________________________________

# %%
# determine Loss function and Optimizer
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 104s 2ms/step - loss: 1.4419 - acc: 0.4787 - val_loss: 2.4660 - val_acc: 0.4189
# Epoch 2/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.9654 - acc: 0.6583 - val_loss: 1.4483 - val_acc: 0.5278
# Epoch 3/30
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.7782 - acc: 0.7270 - val_loss: 0.9209 - val_acc: 0.6899
# Epoch 4/30
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.6514 - acc: 0.7739 - val_loss: 0.8677 - val_acc: 0.7204
# Epoch 5/30
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.5600 - acc: 0.8081 - val_loss: 1.0156 - val_acc: 0.6825
# Epoch 6/30
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.4951 - acc: 0.8306 - val_loss: 1.1275 - val_acc: 0.6644
# Epoch 7/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.4224 - acc: 0.8554 - val_loss: 0.8561 - val_acc: 0.7347
# Epoch 8/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.3519 - acc: 0.8778 - val_loss: 0.9912 - val_acc: 0.7165
# Epoch 9/30
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.3050 - acc: 0.8948 - val_loss: 1.1357 - val_acc: 0.7216
# Epoch 10/30
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.2651 - acc: 0.9074 - val_loss: 0.9678 - val_acc: 0.7331
# Epoch 11/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.2255 - acc: 0.9214 - val_loss: 0.8555 - val_acc: 0.7632
# Epoch 12/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.1984 - acc: 0.9304 - val_loss: 0.8401 - val_acc: 0.7767
# Epoch 13/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.1703 - acc: 0.9420 - val_loss: 0.9780 - val_acc: 0.7447
# Epoch 14/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.1425 - acc: 0.9500 - val_loss: 1.1223 - val_acc: 0.7362
# Epoch 15/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.1355 - acc: 0.9532 - val_loss: 1.0728 - val_acc: 0.7454
# Epoch 16/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.1081 - acc: 0.9623 - val_loss: 1.0655 - val_acc: 0.7575
# Epoch 17/30
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.1012 - acc: 0.9651 - val_loss: 1.1975 - val_acc: 0.7524
# Epoch 18/30
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0989 - acc: 0.9648 - val_loss: 1.1758 - val_acc: 0.7531
# Epoch 19/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.0912 - acc: 0.9678 - val_loss: 1.1370 - val_acc: 0.7591
# Epoch 20/30
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0894 - acc: 0.9683 - val_loss: 1.1744 - val_acc: 0.7473
# Epoch 21/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.0769 - acc: 0.9730 - val_loss: 1.1591 - val_acc: 0.7550
# Epoch 22/30
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.1150 - acc: 0.9636 - val_loss: 9.2714 - val_acc: 0.2863
# Epoch 23/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.1286 - acc: 0.9566 - val_loss: 0.9301 - val_acc: 0.7890
# Epoch 24/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.0747 - acc: 0.9756 - val_loss: 0.9690 - val_acc: 0.7922
# Epoch 25/30
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0481 - acc: 0.9842 - val_loss: 1.4658 - val_acc: 0.7301
# Epoch 26/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.0544 - acc: 0.9807 - val_loss: 1.0743 - val_acc: 0.7816
# Epoch 27/30
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0476 - acc: 0.9835 - val_loss: 1.1385 - val_acc: 0.7776
# Epoch 28/30
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.0562 - acc: 0.9807 - val_loss: 1.0539 - val_acc: 0.7850
# Epoch 29/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.0478 - acc: 0.9836 - val_loss: 1.1033 - val_acc: 0.7833
# Epoch 30/30
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.0554 - acc: 0.9814 - val_loss: 1.2466 - val_acc: 0.7653

# %%
# Test the model
score = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Save the trained weights in to .h5 format
model.save_weights("Yolo_Basic_model2.h5")
print("Saved the model to disk")
# Out:
# 10000/10000 [==============================] - 18s 2ms/step
# Test loss: 1.0456872707366944
# Test accuracy: 0.6804
# Saved the model to disk

# %%
model.save_weights("Yolo_Basic_model2.h5")
print("Saved the model to disk")
from google.colab import files

files.download('Yolo_Basic_model2.h5')
# Out:
# Saved the model to disk
